# %% [markdown]
# ## RRT* Testing AREA

# %%
from rrt_star import *

# %%
x_start = (2, 2)  # Starting node
x_goal = (45, 25)  # Goal node

rrt_star = RrtStar(x_start, x_goal, 0.1, 0.10, 20, 10000)  # step_len, goal_sample_rate, search_radius, iter_max
rrt_star.planning()
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
