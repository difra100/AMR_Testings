# %% [markdown]
# ## RRT* Testing AREA

# %%
from rrt_star import *

# %%
x_start = (2, 2)  # Starting node
x_goal = (45, 25)  # Goal node

rrt_star = RrtStar(x_start, x_goal, 10, 0.1, 20, 100)  # step_len, goal_sample_rate, search_radius, iter_max
rrt_star.planning()
# Out:
# 0
# <class 'list'>
# <class 'rrt_star.Node'>
