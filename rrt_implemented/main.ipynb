# %% [markdown]
# ## RRT* Testing AREA

# %%
from rrt_star import *

# %%
x_start = (2, 2)  # Starting node
x_goal = (45, 25)  # Goal node

rrt_star = RrtStar(x_start, x_goal, 10, 0, 20, 10000)  # step_len, goal_sample_rate, search_radius, iter_max
rrt_star.planning()
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500

# %%
# Out:
# array([[-0.05823352,  0.26822468, -0.35565572, ...,  0.3739126 ,
#         -2.14164593,  0.13904448],
#        [-0.10288206,  1.32077976, -1.41993313, ..., -0.25435849,
#          2.66812762, -0.42042571],
#        [-2.22516734, -1.14818186, -1.40779404, ...,  1.12482949,
#         -0.56007762,  0.2395069 ],
#        ...,
#        [-1.50393996,  0.41376749, -0.46388114, ...,  0.41619364,
#          0.09361868,  0.43964788],
#        [ 1.62963094,  0.46340958,  1.84780203, ..., -0.94225119,
#         -0.1810608 ,  0.65279799],
#        [ 0.07880907, -0.24055978,  1.09594099, ...,  0.13004843,
#         -0.90477516,  0.46546655]])
